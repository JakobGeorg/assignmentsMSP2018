# %%
import matplotlib.pyplot as plt
import numpy as np
import aubio

# %%
filename='/Users/xavob/Documents/avm/avmA.wav'
downsample = 1
samplerate = 0
win_s = 1764 // downsample
hop_s = 441 // downsample

s = aubio.source(filename, samplerate, hop_s)
samplerate = s.samplerate
tolerance = 0.1

pitch_o = aubio.pitch("yin", win_s, hop_s, samplerate) 

pitch_o.set_tolerance(tolerance)

pitchesYIN = []
confidences = [] 
total_frames = 0
while True:
    samples, read = s()
    pitch = pitch_o(samples)[0]
    pitch = int(round(pitch))
    confidence = pitch_o.get_confidence()
    pitchesYIN += [pitch]
    confidences += [confidence]
    total_frames += read
    if read < hop_s:
         break

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1,1,1)    
plt.plot(np.asarray(pitchesYIN))
plt.title ('A-')
# Out:
# Text(0.5,1,'A-')

# %%
filename='/Users/xavob/Documents/avm/avmVE.wav'
downsample = 1
samplerate = 0
win_s = 1764 // downsample
hop_s = 441 // downsample

s = aubio.source(filename, samplerate, hop_s)
samplerate = s.samplerate
tolerance = 0.1

pitch_o = aubio.pitch("yin", win_s, hop_s, samplerate) 

pitch_o.set_tolerance(tolerance)

pitchesYIN = []
confidences = [] 
total_frames = 0
while True:
    samples, read = s()
    pitch = pitch_o(samples)[0]
    pitch = int(round(pitch))
    confidence = pitch_o.get_confidence()
    pitchesYIN += [pitch]
    confidences += [confidence]
    total_frames += read
    if read < hop_s:
         break

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1,1,1)    
plt.plot(np.asarray(pitchesYIN))
plt.title ('-ve')
# Out:
# Text(0.5,1,'-ve')

# %%
filename='/Users/xavob/Documents/avm/avmVE.wav'
downsample = 1
samplerate = 0
win_s = 1764 // downsample
hop_s = 441 // downsample

s = aubio.source(filename, samplerate, hop_s)
samplerate = s.samplerate
tolerance = 0.1

pitch_o = aubio.pitch("yin", win_s, hop_s, samplerate) 

pitch_o.set_tolerance(tolerance)

pitchesYIN = []
confidences = [] 
total_frames = 0
while True:
    samples, read = s()
    pitch = pitch_o(samples)[0]
    pitch = int(round(pitch))
    confidence = pitch_o.get_confidence()
    pitchesYIN += [pitch]
    confidences += [confidence]
    total_frames += read
    if read < hop_s:
         break

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1,1,1)    
plt.plot(np.asarray(pitchesYIN))
plt.title ('Ma-')
# Out:
# Text(0.5,1,'Ma-')

# %%
filename='/Users/xavob/Documents/avm/avmRi1.wav'
downsample = 1
samplerate = 0
win_s = 1764 // downsample
hop_s = 441 // downsample

s = aubio.source(filename, samplerate, hop_s)
samplerate = s.samplerate
tolerance = 0.1

pitch_o = aubio.pitch("yin", win_s, hop_s, samplerate) 

pitch_o.set_tolerance(tolerance)

pitchesYIN = []
confidences = [] 
total_frames = 0
while True:
    samples, read = s()
    pitch = pitch_o(samples)[0]
    pitch = int(round(pitch))
    confidence = pitch_o.get_confidence()
    pitchesYIN += [pitch]
    confidences += [confidence]
    total_frames += read
    if read < hop_s:
         break

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1,1,1)    
plt.plot(np.asarray(pitchesYIN))
plt.title ('-ri-')
# Out:
# Text(0.5,1,'-ri-')

# %%
filename='/Users/xavob/Documents/avm/avmi.wav'
downsample = 1
samplerate = 0
win_s = 1764 // downsample
hop_s = 441 // downsample

s = aubio.source(filename, samplerate, hop_s)
samplerate = s.samplerate
tolerance = 0.1

pitch_o = aubio.pitch("yin", win_s, hop_s, samplerate) 

pitch_o.set_tolerance(tolerance)

pitchesYIN = []
confidences = [] 
total_frames = 0
while True:
    samples, read = s()
    pitch = pitch_o(samples)[0]
    pitch = int(round(pitch))
    confidence = pitch_o.get_confidence()
    pitchesYIN += [pitch]
    confidences += [confidence]
    total_frames += read
    if read < hop_s:
         break

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1,1,1)    
plt.plot(np.asarray(pitchesYIN))
plt.title ('-i-')
# Out:
# Text(0.5,1,'-i-')

# %%
filename='/Users/xavob/Documents/avm/avmA2.wav'
downsample = 1
samplerate = 0
win_s = 1764 // downsample
hop_s = 441 // downsample

s = aubio.source(filename, samplerate, hop_s)
samplerate = s.samplerate
tolerance = 0.1

pitch_o = aubio.pitch("yin", win_s, hop_s, samplerate) 

pitch_o.set_tolerance(tolerance)

pitchesYIN = []
confidences = [] 
total_frames = 0
while True:
    samples, read = s()
    pitch = pitch_o(samples)[0]
    pitch = int(round(pitch))
    confidence = pitch_o.get_confidence()
    pitchesYIN += [pitch]
    confidences += [confidence]
    total_frames += read
    if read < hop_s:
         break

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1,1,1)    
plt.plot(np.asarray(pitchesYIN))
plt.title ('-a')
# Out:
# Text(0.5,1,'-a')
